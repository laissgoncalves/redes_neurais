# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlesPrado23/Bootcamp_TurmaNoite/blob/main/Redes_Neurais/GD_PerceptronClassifier_tarefa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perceptron - Implementation

# %%
from sklearn import datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
np.random.seed(10)

# %%
# Load data
iris=datasets.load_iris()
X = iris.data[0:99,:2]
y = iris.target[0:99]

# %%
iris

# %%
y[0:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
# Plot figure
plt.plot(X[:50, 0], X[:50, 1], 'bo', color='blue', label='0')
plt.plot(X[50:99, 0], X[50:99, 1], 'bo', color='orange', label='1')
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.legend()
# Out:
# <ipython-input-4-706367ddf68f>:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(X[:50, 0], X[:50, 1], 'bo', color='blue', label='0')
# <ipython-input-4-706367ddf68f>:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(X[50:99, 0], X[50:99, 1], 'bo', color='orange', label='1')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20,random_state=20)

# %%
X_train.shape
# Out:
# (79, 2)

# %%
#class Perceptron:

#  def __init__(self, epochs, etha):
#    self.epochs = epochs
#    self.cccccc = cccccc

#  def predict(x,w):
#     ddddddd
#     return output
#  def fit():

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Função Step

# %% [markdown]
# ![Screen Shot 2021-10-25 at 7.40.43 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2021-10-25 at 7.40.47 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Condição para classificação correta ###

# %% [markdown]
# ![Screen Shot 2021-10-25 at 7.38.43 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Classificação incorreta

# %% [markdown]
# ![Screen Shot 2021-10-25 at 7.40.54 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Função custo

# %% [markdown]
#  ![Screen Shot 2021-10-25 at 7.40.59 AM.png](data:image/png;base64,...)

# %% [markdown]
# # Gradiente da Função Custo

# %% [markdown]
# ![Screen Shot 2021-10-25 at 7.58.51 AM.png](data:image/png;base64,...)

# %% [markdown]
# Implementar um PercepetronClassifier
#
# Treinar usando os dados acima
#
# Testar  usando os dados acima
#
# Plotar o resultado final
#
#   * 1a opção -  usando um objeto - Classe
#   * 2a opção - usando def function

# %%
class Perceptron_Bootcamp(object):

  def __init__(self,input_size,epochs=50,etha=0.01):
    self.W = np.zeros(1+input_size)
    #b = 0
    self.epochs = epochs
    self.etha = etha

 ### Definir outras funcões

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)


ax.plot3D(x1,x2,Z_1);
ax.scatter3D( X[:50, 0], X[:50, 1],Z_2,color='red');
ax.scatter3D( X[50:99, 0], X[50:99, 1],Z_3, c='green');
